# %%
import pandas as pd
import numpy as np

# %%
order_product = pd.read_csv('order_products.csv')
order = pd.read_csv('orders.csv')

# %%
order_product.head(20)
# Out:
#     order_id  product_id  add_to_cart_order
# 0          2       33120                  1
# 1          2       28985                  2
# 2          2        9327                  3
# 3          2       45918                  4
# 4          2       30035                  5
# 5          2       17794                  6
# 6          2       40141                  7
# 7          2        1819                  8
# 8          2       43668                  9
# 9          3       33754                  1
# 10         3       24838                  2
# 11         3       17704                  3
# 12         3       21903                  4
# 13         3       17668                  5
# 14         3       46667                  6
# 15         3       17461                  7
# 16         3       32665                  8
# 17         4       46842                  1
# 18         4       26434                  2
# 19         4       39758                  3

# %%
order.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %% [markdown]
# Eval_set column contains three distinct values:
# 1. Train: The latest order for each customer that is able to join with order_product
# 2. Test: The latest order for each customer that is not able to join with order_product
# 3. Prior: All the orders that are not the latest order

# %%
m = order['order_id'].unique()
print("Distinct orders in order table:", m.shape[0])
n = order_product['order_id'].unique()
print("Distinct orders in order_product table:", n.shape[0])
# Out:
# Distinct orders in order table: 3421083
# Distinct orders in order_product table: 3346083

# %%
order['rank'] = order.groupby(['user_id'])['order_number'].rank(ascending=False)
order.head(30)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %%
table_new = pd.merge(order, order_product, on='order_id', how='left')
table_new
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 33894101    272231   206209            14          6                 14
# 33894102    272231   206209            14          6                 14
# 33894103    272231   206209            14          6                 14
# 33894104    272231   206209            14          6                 14
# 33894105    272231   206209            14          6                 14
#
#           days_since_prior_order  rank  product_id  add_to_cart_order
# ...

# %%
latest_order = table_new[table_new['rank']==1]
latest_order
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 59         1187899        1            11          4                  8
# 60         1187899        1            11          4                  8
# 61         1187899        1            11          4                  8
# 62         1187899        1            11          4                  8
# 63         1187899        1            11          4                  8
# ...            ...      ...           ...        ...                ...
# 33894101    272231   206209            14          6                 14
# 33894102    272231   206209            14          6                 14
# 33894103    272231   206209            14          6                 14
# 33894104    272231   206209            14          6                 14
# 33894105    272231   206209            14          6                 14
#
#           days_since_prior_order  rank  product_id  add_to_cart_order
# ...

# %%
test = latest_order[latest_order['product_id'].isnull()]
test
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# 33892542   2728930   206202            23          2                 17
# 33892729    350108   206204             5          4                 14
# 33893066   1043943   206206            68          0                 20
# 33893290   2821651   206207            17          2                 13
# 33893968    803273   206208            50          5                 11
#
#           days_since_prior_order  rank  product_id  add_to_cart_order
# ...

# %%
train = table_latest[table_latest['product_id'].notnull()]
train
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         1187899        1            11          4                  8
# 1         1187899        1            11          4                  8
# 2         1187899        1            11          4                  8
# 3         1187899        1            11          4                  8
# 4         1187899        1            11          4                  8
# ...           ...      ...           ...        ...                ...
# 1459612    272231   206209            14          6                 14
# 1459613    272231   206209            14          6                 14
# 1459614    272231   206209            14          6                 14
# 1459615    272231   206209            14          6                 14
# 1459616    272231   206209            14          6                 14
#
#          days_since_prior_order  rank  product_id  add_to_cart_order
# ...

# %%
prior = order[order['rank']!=1]
prior
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421077   2558525   206209             9          4                 15
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
#
#          days_since_prior_order  rank
# 0                           NaN  11.0
# ...
