# %%
import pandas as pd
import numpy as np

# %%
aisle = pd.read_csv('aisles.csv')
department = pd.read_csv('departments.csv')
order_product = pd.read_csv('order_products.csv')
order = pd.read_csv('orders.csv')
product = pd.read_csv('products.csv')

# %%
df1 = pd.merge(product, aisle, on='aisle_id', how='left')

# %%
df2 = pd.merge(df1, department, on='department_id', how='left')

# %%
df3 = pd.merge(order_product, df2, on='product_id', how='left')

# %%
table_new = pd.merge(order, df3, on='order_id', how='left')
table_new
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 33894101    272231   206209            14          6                 14
# 33894102    272231   206209            14          6                 14
# 33894103    272231   206209            14          6                 14
# 33894104    272231   206209            14          6                 14
# 33894105    272231   206209            14          6                 14
#
#           days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
table_new['order_rank'] = table_new.groupby(['user_id','product_id'])['order_number'].rank()

# %%
def reorder(order_rank):
    if order_rank == 1:
        n = 0
    else: 
        n = 1
    return n
table_new['reordered'] = table_new['order_rank'].apply(reorder)
table_new.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2539329        1             1          2                  8
# 2    2539329        1             1          2                  8
# 3    2539329        1             1          2                  8
# 4    2539329        1             1          2                  8
# 5    2398795        1             2          3                  7
# 6    2398795        1             2          3                  7
# 7    2398795        1             2          3                  7
# 8    2398795        1             2          3                  7
# 9    2398795        1             2          3                  7
# 10   2398795        1             2          3                  7
# 11    473747        1             3          3                 12
# 12    473747        1             3          3                 12
# ...
